# %%
print("HEllo")
# Out:
# HEllo
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import re

with open("BMS.md", "r", encoding="utf-8") as f:
    content = f.read()

# Remove multiple blank lines
content = re.sub(r'\n{3,}', '\n\n', content)

# Trim extra spaces at line ends
content = re.sub(r'[ \t]+$', '', content, flags=re.MULTILINE)

# Fix spacing around headers
content = re.sub(r'\n?#+[^\n]*\n?', lambda m: '\n' + m.group().strip() + '\n', content)

with open("cleaned_BMS.md", "w", encoding="utf-8") as f:
    f.write(content)

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
# from langchain.embeddings import OpenAIEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
import openai 
from dotenv import load_dotenv
import os
import shutil

# %%
load_dotenv()
openai.api_key = os.environ['OpenAIKey']
CHROMA_PATH = "chroma"
DATA_PATH = "CollegeInfo"

# %%
def main():
    generate_data_store()

# %%
def generate_data_store():
    documents = load_documents()
    chunks = split_text(documents)
    save_to_chroma(chunks)

# %%
def load_documents():
    loader = DirectoryLoader(DATA_PATH, glob="*.md")
    documents = loader.load()
    return documents

# %%
def split_text(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )
    chunks = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

    document = chunks[10]
    print(document.page_content)
    print(document.metadata)

    return chunks

# %%
def save_to_chroma(chunks: list[Document]):
    # Clear out the database first.
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)

    # Create a new DB from the documents.
    db = Chroma.from_documents(
        chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH
    )
    db.persist()
    print(f"Saved {len(chunks)} chunks to {CHROMA_PATH}.")

# %%
if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rohan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# Error loading file CollegeInfo\cleaned_BMS.md
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[5], line 2, in main()
#       1 def main():
# ----> 2     generate_data_store()
#
# Cell In[6], line 2, in generate_data_store()
#       1 def generate_data_store():
# ----> 2     documents = load_documents()
#       3     chunks = split_text(documents)
#       4     save_to_chroma(chunks)
#
# Cell In[7], line 3, in load_documents()
#       1 def load_documents():
#       2     loader = DirectoryLoader(DATA_PATH, glob="*.md")
# ----> 3     documents = loader.load()
#       4     return documents
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\langchain_community\document_loaders\directory.py:182, in DirectoryLoader.lazy_load(self)
#     180 else:
#     181     for i in items:
# --> 182         yield from self._lazy_load_file(i, p, pbar)
#     184 if pbar:
#     185     pbar.close()
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\langchain_community\document_loaders\directory.py:220, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     218     else:
#     219         logger.error(f"Error loading file {str(item)}")
# --> 220         raise e
#     221 finally:
#     222     if pbar:
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\langchain_community\document_loaders\directory.py:210, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     208 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     209 try:
# --> 210     for subdoc in loader.lazy_load():
#     211         yield subdoc
#     212 except NotImplementedError:
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\langchain_community\document_loaders\unstructured.py:88, in UnstructuredBaseLoader.lazy_load(self)
#      86 def lazy_load(self) -> Iterator[Document]:
#      87     """Load file."""
# ---> 88     elements = self._get_elements()
#      89     self._post_process_elements(elements)
#      90     if self.mode == "elements":
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\langchain_community\document_loaders\unstructured.py:180, in UnstructuredFileLoader._get_elements(self)
#     178 if isinstance(self.file_path, Path):
#     179     self.file_path = str(self.file_path)
# --> 180 return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\partition\auto.py:415, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, skip_infer_table_types, ssl_verify, ocr_languages, languages, detect_language_per_element, pdf_infer_table_structure, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, xml_keep_tags, data_source_metadata, metadata_filename, request_timeout, hi_res_model_name, model_name, date_from_file_object, starting_page_number, **kwargs)
#     413 elif filetype == FileType.MD:
#     414     _partition_md = _get_partition_with_extras("md")
# --> 415     elements = _partition_md(
#     416         filename=filename,
#     417         file=file,
#     418         include_page_breaks=include_page_breaks,
#     419         infer_table_structure=infer_table_structure,
#     420         languages=languages,
#     421         detect_language_per_element=detect_language_per_element,
#     422         **kwargs,
#     423     )
#     424 elif filetype == FileType.PDF:
#     425     _partition_pdf = _get_partition_with_extras("pdf")
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\elements.py:591, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     589 @functools.wraps(func)
#     590 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 591     elements = func(*args, **kwargs)
#     592     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     594     regex_metadata: dict["str", "str"] = call_args.get("regex_metadata", {})
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\file_utils\filetype.py:618, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     616 @functools.wraps(func)
#     617 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 618     elements = func(*args, **kwargs)
#     619     params = get_call_args_applying_defaults(func, *args, **kwargs)
#     620     include_metadata = params.get("include_metadata", True)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\file_utils\filetype.py:582, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     580 @functools.wraps(func)
#     581 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 582     elements = func(*args, **kwargs)
#     583     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     584     include_metadata = call_args.get("include_metadata", True)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\chunking\dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\partition\md.py:112, in partition_md(filename, file, text, url, include_page_breaks, include_metadata, parser, metadata_filename, metadata_last_modified, chunking_strategy, languages, detect_language_per_element, date_from_file_object, **kwargs)
#     108     text = response.text
#     110 html = markdown.markdown(text, extensions=["tables"])
# --> 112 return partition_html(
#     113     text=html,
#     114     include_page_breaks=include_page_breaks,
#     115     include_metadata=include_metadata,
#     116     parser=parser,
#     117     source_format="md",
#     118     metadata_filename=metadata_filename,
#     119     metadata_last_modified=metadata_last_modified or last_modification_date,
#     120     languages=languages,
#     121     detect_language_per_element=detect_language_per_element,
#     122     detection_origin=DETECTION_ORIGIN,
#     123 )
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\elements.py:591, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     589 @functools.wraps(func)
#     590 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 591     elements = func(*args, **kwargs)
#     592     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     594     regex_metadata: dict["str", "str"] = call_args.get("regex_metadata", {})
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\file_utils\filetype.py:618, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     616 @functools.wraps(func)
#     617 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 618     elements = func(*args, **kwargs)
#     619     params = get_call_args_applying_defaults(func, *args, **kwargs)
#     620     include_metadata = params.get("include_metadata", True)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\file_utils\filetype.py:582, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     580 @functools.wraps(func)
#     581 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 582     elements = func(*args, **kwargs)
#     583     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     584     include_metadata = call_args.get("include_metadata", True)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\chunking\dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\partition\html.py:149, in partition_html(filename, file, text, url, encoding, include_page_breaks, include_metadata, headers, ssl_verify, parser, source_format, html_assemble_articles, metadata_filename, metadata_last_modified, skip_headers_and_footers, chunking_strategy, languages, detect_language_per_element, detection_origin, date_from_file_object, **kwargs)
#     144 if skip_headers_and_footers:
#     145     document = filter_footer_and_header(document)
#     147 elements = list(
#     148     apply_lang_metadata(
# --> 149         document_to_element_list(
#     150             document,
#     151             sortable=False,
#     152             include_page_breaks=include_page_breaks,
#     153             last_modification_date=metadata_last_modified or last_modification_date,
#     154             source_format=source_format if source_format else None,
#     155             detection_origin=detection_origin,
#     156             **kwargs,
#     157         ),
#     158         languages=languages,
#     159         detect_language_per_element=detect_language_per_element,
#     160     ),
#     161 )
#     163 # Note(yuming): Rip off page_number metadata fields here
#     164 # until we have a better way to handle page counting for html files
#     165 for element in elements:
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\partition\common.py:559, in document_to_element_list(document, sortable, include_page_breaks, last_modification_date, infer_list_items, source_format, detection_origin, sort_mode, languages, starting_page_number, **kwargs)
#     556 """Converts a DocumentLayout or HTMLDocument object to a list of unstructured elements."""
#     557 elements: list[Element] = []
# --> 559 num_pages = len(document.pages)
#     560 for page_number, page in enumerate(document.pages, start=starting_page_number):
#     561     page_elements: list[Element] = []
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\xml.py:54, in XMLDocument.pages(self)
#      52 """Gets all elements from pages in sequential order."""
#      53 if self._pages is None:
# ---> 54     self._pages = self._parse_pages_from_element_tree()
#      55 return super().pages
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\html.py:173, in HTMLDocument._parse_pages_from_element_tree(self)
#     170     continue
#     172 if _is_text_tag(tag_elem):
# --> 173     _page_elements, descendanttag_elems = _process_text_tag(tag_elem)
#     174     page.elements.extend(_page_elements)
#     176 elif _is_container_with_text(tag_elem):
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\html.py:630, in _process_text_tag(tag_elem, include_tail_text)
#     627             page_elements.append(element)
#     629 else:
# --> 630     element = _parse_tag(tag_elem, include_tail_text)
#     631     if element is not None:
#     632         page_elements.append(element)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\html.py:438, in _parse_tag(tag_elem, include_tail_text)
#     436 if not text:
#     437     return None
# --> 438 return _text_to_element(
#     439     text,
#     440     tag_elem.tag,
#     441     ancestortags,
#     442     links=links,
#     443     emphasized_texts=emphasized_texts,
#     444     depth=depth,
#     445 )
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\html.py:486, in _text_to_element(text, tag, ancestortags, depth, links, emphasized_texts)
#     484 if len(text) < 2:
#     485     return None
# --> 486 elif is_narrative_tag(text, tag):
#     487     return HTMLNarrativeText(
#     488         text,
#     489         tag=tag,
#    (...)
#     492         emphasized_texts=emphasized_texts,
#     493     )
#     494 elif is_heading_tag(tag) or is_possible_title(text):
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\documents\html.py:536, in is_narrative_tag(text, tag)
#     534 def is_narrative_tag(text: str, tag: str) -> bool:
#     535     """Uses tag information to infer whether text is narrative."""
# --> 536     return tag not in HEADING_TAGS and is_possible_narrative_text(text)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\partition\text_type.py:80, in is_possible_narrative_text(text, cap_threshold, non_alpha_threshold, languages, language_checks)
#      75 # NOTE(robinson): it gets read in from the environment as a string so we need to
#      76 # cast it to a float
#      77 cap_threshold = float(
#      78     os.environ.get("UNSTRUCTURED_NARRATIVE_TEXT_CAP_THRESHOLD", cap_threshold),
#      79 )
# ---> 80 if exceeds_cap_ratio(text, threshold=cap_threshold):
#      81     trace_logger.detail(f"Not narrative. Text exceeds cap ratio {cap_threshold}:\n\n{text}")  # type: ignore # noqa: E501
#      82     return False
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\partition\text_type.py:276, in exceeds_cap_ratio(text, threshold)
#     263 """Checks the title ratio in a section of text. If a sufficient proportion of the words
#     264 are capitalized, that can be indicated on non-narrative text (i.e. "1A. Risk Factors").
#     265
#    (...)
#     272     the function returns True
#     273 """
#     274 # NOTE(robinson) - Currently limiting this to only sections of text with one sentence.
#     275 # The assumption is that sections with multiple sentences are not titles.
# --> 276 if sentence_count(text, 3) > 1:
#     277     return False
#     279 if text.isupper():
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\partition\text_type.py:225, in sentence_count(text, min_length)
#     214 def sentence_count(text: str, min_length: Optional[int] = None) -> int:
#     215     """Checks the sentence count for a section of text. Titles should not be more than one
#     216     sentence.
#     217
#    (...)
#     223         The min number of words a section needs to be for it to be considered a sentence.
#     224     """
# --> 225     sentences = sent_tokenize(text)
#     226     count = 0
#     227     for sentence in sentences:
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\unstructured\nlp\tokenize.py:30, in sent_tokenize(text)
#      28 """A wrapper around the NLTK sentence tokenizer with LRU caching enabled."""
#      29 _download_nltk_package_if_not_present(package_category="tokenizers", package_name="punkt")
# ---> 30 return _sent_tokenize(text)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File c:\Users\rohan\miniconda3\envs\FDS\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\rohan/nltk_data'
#     - 'c:\\Users\\rohan\\miniconda3\\envs\\FDS\\nltk_data'
#     - 'c:\\Users\\rohan\\miniconda3\\envs\\FDS\\share\\nltk_data'
#     - 'c:\\Users\\rohan\\miniconda3\\envs\\FDS\\lib\\nltk_data'
#     - 'C:\\Users\\rohan\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
